# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carga db

# %%
df = sns.load_dataset('titanic')

# %% [markdown]
# ### Analizar relacion pclass y fare

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='pclass', y='fare', data=df)
plt.title('Distribución de tarifas por clase')
plt.xlabel('Clase del pasajero')
plt.ylabel('Tarifa')
plt.show()

# %% [markdown]
# ### Histograma de edades agrupadas por clase

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df, x='age', hue='pclass', multiple='stack', bins=30, kde=True, palette='viridis', hue_order=[1, 2, 3])
plt.title('Distribución de edades por clase')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Clase', labels=['Primera', 'Segunda', 'Tercera'])
plt.show()

# %% [markdown]
# ### Grafica variable categorica "sex" y supervivencia

# %%
sns.countplot(x='sex', data=df, hue='survived')
plt.title('Distribución de pasajeros por género y supervivencia')
plt.xlabel('Género')
plt.ylabel('Cantidad')
plt.legend(title='Supervivencia', labels=['No', 'Sí'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mateo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: np.float64(-0.4)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 11
# ...

# %% [markdown]
# ### 2. Probabilidad de supervivencia menores de 18

# %%
menores_18 = df[df['age'] < 18]

# %%
probabilidad_supervivencia = menores_18['survived'].mean()
print(f'La probabilidad de que un pasajero menor de 18 años haya sobrevivido es: {probabilidad_supervivencia:.2%}')
# Out:
# La probabilidad de que un pasajero menor de 18 años haya sobrevivido es: 53.98%
